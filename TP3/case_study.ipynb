# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pandas as pd 
import numpy as np

# %%
gdf=gpd.read_file('files\huilerie_sb32_SpatialJoin.shp')

# %%
gdf.sample(15)
# Out:
#     Join_Count  TARGET_FID  IDE   N              DELEG  \
# 79           1          79   80  79             REGUEB
# 63           1          63   64  46      OULED HAFFOUZ
# 35           1          35   36  22         SOUK EJDID
# 36           1          36   37  23         SOUK EJDID
# 24           1          24   25  11  SIDI BOUZID OUEST
# 64           1          64   65  47      OULED HAFFOUZ
# 20           1          20   21   7    SIDI BOUZID EST
# 4            1           4    5  67             REGUEB
# 31           1          31   32  18         BIR LEHFAY
# 25           1          25   26  12  SIDI BOUZID OUEST
# 38           1          38   39  25         BIR LEHFAY
# 39           1          39   40  26         BIR LEHFAY
# 66           1          66   67  49      OULED HAFFOUZ
# 17           1          17   18   2    SIDI BOUZID EST
# 42           1          42   43  29  SIDI ALI BEN AOUN
#
#                                           PROP              IMADA  \
# 79                YOUSSEF BEN ENNOURI MABROUKI           Fatnassa
# 63          HABIB EL MOULDI AOUNI ET COMPAGNIE         Sidi Khlif
# 35                              ABDELKERIM AFI         Souk Ejdid
# 36                            HAMMADI CHOUAIBI         Souk Ejdid
# 24                 NOUREDDINE BEN MAAMER NASRI      Oum Laadham 2
# 64               MABROUKI MOHAMED BEN LAKHDHAR       Dhouibet Sud
# 20                   HERITIEERS BECHIR KAMMOUN             Lahwez
# 4                 IBRAHIM JALLALI ET COMPAGNIE       Centre ville
# 31                       MONCEF BEN HCINE DHAI            Lemzara
# 25            EL HADJ AMMAR BEN LAKHDHAR RABHI      Oum Laadham 2
# 38                MOHAMED ET ABDELLATIF EDDALI         Bir lehfay
# 39  EMBERIKA EDDALI ET RIDHA BEN LAZHAR AKRIMI         Bir lehfay
# 66                  BELGACEM EL HEDI CHOUCHANE      Ouled Haffouz
# 17             JAMILA BENT ALI BEN SADOK NSIRI           Lessouda
# 42                      ALI BEN LAMINE ABDELLI  Sidi Ali Ben Aoun
#
#                          LOCAL  CAP_TRANSF  CAP_STOCK                  TYPE  \
# 79                    Lekhcham          20        130               Moderne
# 63                     Mharzia          16         50        Traditionnelle
# 35                  Souk Ejdid          40         80       Chaine continue
# 36                  Souk Ejdid          10         40               Moderne
# 24               Oum Laadham 2          24         68       Chaine continue
# 64              Km 80 Errenzez          24         50               Moderne
# 20                      Lahwez          20        180               Moderne
# 4                       Regueb          15         60               Moderne
# 31                     Lemzara          35        150       Chaine continue
# 25               Oum Laadham 2          10         60               Moderne
# 38                Centre ville          20         50               Moderne
# 39                Centre ville          35         60  Chaine continue/Mod.
# 66  Municipalité Ouled Haffouz          20        100        Traditionnelle
# 17                    Lessouda          15         50               Moderne
# 42                Centre ville          30        125               Moderne
#
#     IDE_1       SURFACE   PERIMETRE  ADM_COD      ADM_GOV            ADM_DEL  \
# 79     12  1.047813e+09  148378.303     4356  SIDI BOUZID             REGUEB
# 63      5  3.935621e+08  105268.660     4355  SIDI BOUZID      OULED HAFFOUZ
# 35     11  3.533654e+08  104890.276     4362  SIDI BOUZID         SOUK JEDID
# 36     11  3.533654e+08  104890.276     4362  SIDI BOUZID         SOUK JEDID
# 24      9  4.274275e+08  148190.227     4351  SIDI BOUZID  SIDI BOUZID OUEST
# 64      5  3.935621e+08  105268.660     4355  SIDI BOUZID      OULED HAFFOUZ
# 20      9  4.274275e+08  148190.227     4351  SIDI BOUZID  SIDI BOUZID OUEST
# 4      12  1.047813e+09  148378.303     4356  SIDI BOUZID             REGUEB
# 31      6  5.076110e+08  123777.450     4357  SIDI BOUZID       BIR EL HAFEY
# 25      9  4.274275e+08  148190.227     4351  SIDI BOUZID  SIDI BOUZID OUEST
# 38      6  5.076110e+08  123777.450     4357  SIDI BOUZID       BIR EL HAFEY
# 39      6  5.076110e+08  123777.450     4357  SIDI BOUZID       BIR EL HAFEY
# 66      5  3.935621e+08  105268.660     4355  SIDI BOUZID      OULED HAFFOUZ
# 17     10  7.858220e+08  193458.436     4352  SIDI BOUZID    SIDI BOUZID EST
# 42      8  6.087535e+08  124663.705     4358  SIDI BOUZID  SIDI ALI BEN AOUN
#
#                           geometry
# 79  POINT (588994.535 3875110.592)
# 63  POINT (577769.567 3890769.809)
# 35  POINT (551713.390 3867488.424)
# 36  POINT (551540.516 3866375.824)
# 24  POINT (534482.429 3888311.385)
# 64  POINT (589925.484 3879140.510)
# 20  POINT (545290.119 3876512.136)
# 4   POINT (571692.977 3857142.163)
# 31  POINT (524290.712 3867652.779)
# 25  POINT (536248.126 3887554.658)
# 38  POINT (517659.666 3864708.201)
# 39  POINT (518128.993 3865155.528)
# 66  POINT (576946.454 3881590.207)
# 17  POINT (548551.134 3884039.968)
# 42  POINT (513208.081 3856462.697)

# %%
gdf['DELEG'].value_counts()
# Out:
# DELEG
# OULED HAFFOUZ        28
# REGUEB               13
# SIDI BOUZID EST      11
# SIDI BOUZID OUEST     8
# SIDI ALI BEN AOUN     5
# JILMA                 4
# BIR LEHFAY            3
# SOUK EJDID            3
# ESSABALA              2
# EL MEKNASSI           2
# MANZEL BOUZAEN        2
# Name: count, dtype: int64

# %%
fig=plt.figure(figsize=(12,6))
plt.title(' La capacité de stockage total pour chaque délégation', size =20  )
plt.bar(gdf['DELEG'],gdf['CAP_STOCK'])
plt.xticks(rotation=75)
plt.tight_layout()
plt.show()

# %%
huilerie=gpd.read_file('tag32_sb32_SpatialJoin.shp')

# %%
huilerie.columns
# Out:
# Index(['Join_Count', 'TARGET_FID', 'AREA', 'PERIMETER', 'GRID_CODE',
#        'CLASS_FIN', 'TAG_OCS', 'IDE', 'SURFACE', 'PERIMETRE', 'ADM_COD',
#        'ADM_GOV', 'ADM_DEL', 'geometry'],
#       dtype='object')

# %%
huilerie.sample(5)
# Out:
#         Join_Count  TARGET_FID    AREA  PERIMETER  GRID_CODE  \
# 178087           1      178087   800.0      120.0          5
# 1663             1        1663  1600.0      160.0          2
# 103969           1      103969  2400.0      200.0          5
# 48855            1       48855   400.0       80.0         13
# 199611           1      199611  6800.0      400.0         11
#
#                                           CLASS_FIN  TAG_OCS  IDE  \
# 178087                                     parcours      700    2
# 1663                                        céréale      110    4
# 103969                                     parcours      700   11
# 48855   Culture maraichère de printemps sous olivie      404    5
# 199611              Culture maraichère de printemps      403    1
#
#              SURFACE   PERIMETRE  ADM_COD      ADM_GOV           ADM_DEL  \
# 178087  5.896075e+08  129555.252     4360  SIDI BOUZID  MENZEL BOUZAIENE
# 1663    6.484966e+08  126497.363     4354  SIDI BOUZID             JILMA
# 103969  3.533654e+08  104890.276     4362  SIDI BOUZID        SOUK JEDID
# 48855   3.935621e+08  105268.660     4355  SIDI BOUZID     OULED HAFFOUZ
# 199611  1.119103e+09  203182.604     4361  SIDI BOUZID          MEZZOUNA
#
#                                                  geometry
# 178087  POLYGON ((546609.562 3838945.500, 546589.562 3...
# 1663    POLYGON ((536189.562 3920445.500, 536189.562 3...
# 103969  POLYGON ((550589.562 3865545.500, 550609.562 3...
# 48855   POLYGON ((573269.562 3884985.500, 573269.562 3...
# 199611  POLYGON ((567689.562 3823345.500, 567689.562 3...

# %%
huilerie['ADM_DEL'].value_counts()
# Out:
# ADM_DEL
# REGUEB                 43843
# SIDI BOUZID OUEST      26611
# SIDI BOUZID EST        24512
# MEZZOUNA               21025
# JILMA                  19551
# BIR EL HAFEY           17207
# MENZEL BOUZAIENE       13511
# SIDI ALI BEN AOUN      12918
# CEBALAT OULED ASKER    11705
# SOUK JEDID              8987
# OULED HAFFOUZ           8751
# MEKNASSY                5374
# Name: count, dtype: int64

# %%
huilerie_olive=huilerie[huilerie['CLASS_FIN']=='Olivier']

# %%
gdf.dropna(subset=['ADM_DEL'], inplace=True)

# %%
fig=plt.figure(figsize=(12,6))
plt.title(' La surface des oliviers pour chaque délégation', size =20  )
plt.bar(huilerie_olive['ADM_DEL'].astype(str),huilerie_olive['AREA'])
plt.xticks(rotation=75)
plt.tight_layout()
plt.xlabel('Delegation')
plt.ylabel('Surface Area')
plt.show()
